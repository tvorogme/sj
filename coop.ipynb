# %%
import pickle
from collections import Counter
import collections
import numpy as np

# %%
sim_to_work = pickle.load(open("sim_to_work.pck", "rb"))

# %%
vacancy_by_name = pickle.load(open("vacancy_by_name.pck", "rb"))

# %%
vacancy_by_name['e93e7dc6aac1811f5d9e0e872665f74b6d1e9c02']
# Out:
# {'candidat': 'Опыт работы от 3 лет, Знание складской и транспортной логистики,\nуверенный пользователь ПК, 1С\nЖелательно проживание в районе МО, г. Одинцово',
#  'clear_skills': ['опыт работа',
#   'знание транспортный логистика',
#   'знание складской',
#   'уверенный пользователь',
#   'проживание район'],
#  'dirty_skills': ['опыт работы',
#   'знание транспортной логистики',
#   'знание складской',
#   'уверенный пользователь',
#   'проживание в районе'],
#  'drive_license': '',
#  'education_value': 'неполное высшее',
#  'employer_type_value': 'прямой работодатель',
#  'experience_value': 'от 3 до 6 лет',
#  'id': 'e93e7dc6aac1811f5d9e0e872665f74b6d1e9c02',
#  'id_client': 'b2fe7d405fb9e1ab3f06656c244e163def331c75',
#  'languages': [],
#  'metro': [],
#  'payment_from': 45000,
#  'payment_to': 0,
#  'place_of_work_value': 'на территории работодателя',
#  'profession': 'Кладовщик',
#  'profession_tree_id': 301,
#  'profession_tree_name': 'Кладовщик',
#  'town': 'Москва',
#  'type_of_work_value': 'полный рабочий день',
#  'vac': array([ -1.88891534e-02,  -9.16511472e-03,   1.08545471e-03,
#           2.96772718e-02,   2.89021116e-02,  -1.94630399e-02,
#           1.69814117e-02,  -1.65599398e-02,  -4.01270390e-03,
#          -1.28482580e-02,  -3.56849991e-02,  -2.05223374e-02,
#          -1.20154181e-02,   2.15066690e-02,   4.12042631e-04,
#          -1.37148490e-02,  -5.42430533e-03,   1.55146681e-02,
#          -2.66060675e-03,  -4.24227584e-03,  -1.06350370e-02,
#           5.92788449e-04,   1.29441358e-02,   3.30612226e-03,
#          -2.54918151e-02,  -5.54481056e-03,  -1.40308114e-02,
#          -3.31941284e-02,  -5.49950004e-02,  -9.15893726e-03,
#          -1.43714203e-03,  -9.43781063e-03,  -3.61082633e-03,
#          -9.28525068e-03,  -2.68517062e-02,  -1.31661110e-02,
#          -1.93536989e-02,   1.20147270e-04,  -3.59702483e-02,
#           1.14870807e-02,   2.04897542e-02,   1.26672769e-02,
#           9.89494100e-03,  -5.61377667e-02,  -1.12832536e-03,
#          -3.39476503e-02,   1.55604472e-02,   3.99982966e-02,
#           4.57615815e-02,  -1.24543440e-02,  -5.27247740e-03,
#          -3.59320175e-03,   5.91601385e-03,   1.07931453e-04,
#          -1.08215194e-02,   3.14081870e-02,   2.15664762e-03,
#          -1.23549700e-02,  -1.48011763e-02,  -5.01676230e-04,
#           5.97390020e-03,   1.38528587e-03,  -6.51158698e-05,
#           2.83144247e-02,   2.41860021e-02,  -2.12075952e-02,
#           1.32696340e-02,   2.85142083e-02,   4.92717931e-03,
#           2.19517667e-02,  -9.98622831e-03,  -8.02902970e-03,
#           3.29600740e-03,  -2.91873682e-02,  -3.54303867e-02,
#           3.35175432e-02,   4.50040679e-03,   9.61257704e-03,
#           3.52060469e-03,   2.39654500e-02,  -3.41569372e-02,
#           7.16342824e-04,  -3.17258597e-03,  -1.31640537e-02,
#          -8.38990137e-03,   1.65217184e-02,  -1.64879803e-02,
#          -2.77087633e-02,  -2.76525728e-02,  -3.34572084e-02,
#          -3.19794901e-02,   6.11378532e-03,  -1.12167830e-02,
#           2.46669352e-02,   1.02418428e-02,  -1.61550904e-03,
#          -2.54015699e-02,  -8.92263185e-03,  -8.88008066e-03,
#           8.49174219e-04,   7.55554624e-03,  -9.47400648e-03,
#          -3.23826424e-03,   2.86520496e-02,  -1.43055171e-02,
#          -4.07728516e-02,   1.83701478e-02,   2.64994975e-04,
#           2.05203407e-02,   3.59879900e-03,   2.99672149e-02,
#          -3.11997300e-03,  -3.64084175e-04,  -2.77271941e-02,
#           6.17252057e-03,   9.23105888e-03,   2.87168380e-02,
#          -2.96796905e-03,  -2.24314630e-02,  -1.98408905e-02,
#           1.03943376e-02,  -1.88489165e-02,   1.18338047e-02,
#           1.37494924e-02,   1.66176483e-02,  -1.12105189e-02,
#           8.54537543e-03,  -7.80831696e-03,  -7.99709093e-03,
#           4.39400040e-03,   2.72694360e-02,  -3.27451155e-03,
#          -1.85215124e-03,  -4.02296670e-02,   4.24528681e-03,
#           1.10039106e-02,  -1.97673701e-02,  -2.53264364e-02,
#          -4.36767191e-02,   2.76078116e-02,   8.67179316e-03,
#           1.30649155e-03,  -2.47606467e-02,  -1.78250335e-02,
#           7.73124723e-03,   4.27804003e-03,  -1.06442245e-02,
#           2.09103413e-02,  -6.99510658e-03,   1.26167191e-02,
#          -3.18813287e-02,   9.26875509e-03,  -1.20333387e-02,
#           2.08178665e-02,   1.00839250e-02,   4.53267805e-03,
#          -2.64380332e-02,  -2.71416660e-02,   1.33091789e-02,
#          -2.42010150e-02,  -2.62667742e-02,   1.00792628e-02,
#          -3.92728340e-04,   3.20492238e-02,   9.58760362e-03], dtype=float32),
#  'work': '1. Взвешивание, прием на склад, хранение и выдача со склада материальных ценностей.\n2. Проверка соответствия между принимаемыми ценностями и информацией о них в сопроводительных документах.\n3. Перемещение материальные ценности к местам хранения вручную или при помощи средств механизации, с сортировкой их по определенным критериям.\n4. Руководство работами по выгрузке, расположению внутри склада, погрузке товаров.\n5. Комплектация материальные ценности в соответствии с заявками потребителей.\n6. Содействие в сохранности складируемых товарно-материальных ценностей.\n7. Обеспечение соблюдения режимов хранения товарно-материальных ценностей.\n8. Составление установленной отчетности, дефектной ведомости на неисправные товары, рекламации, акты о недостаче, порче, списании материалов.\n9. Обеспечение соблюдения правил оформления и сдачи отчетных документов.\n10. Ведение учета складских операций.\n11. Участие в инвентаризации товарно-материальных ценностей.\n12. Осуществление надзора за комплектностью, исправностью противопожарных средств, состоянием оборудования, помещений инвентаря на складе, обеспечивает их своевременное обслуживание и ремонт.\n13. Контроль состояния техники безопасности и принятие мер по устранению выявленных недостатков.\n14. Фиксация нарушений правил производственной санитарии, инструкций по охране труда.\n15. Выполнение отдельных служебных поручений руководителя.'}

# %%
resume = pickle.load(open("resume_with_days.pkl", "rb"))

# %%
skills_by_theme = collections.defaultdict(lambda: [])

for vac in vacancy_by_name:
    vac = vacancy_by_name[vac]
    skills_by_theme[vac['profession_tree_name']].extend(vac['dirty_skills'])

# %%
for theme in skills_by_theme:
    skills_by_theme[theme] = [i[0][0] for i in collections.Counter(skills_by_theme[theme]).most_common(6000)]

# %%
def get_jobs(resume_id):
    ans = {}
    for job in resume[resume_id]['work_history']:
        ans[int(job['monthbeg'])/12 + int(job['yearbeg'])] = job
    return dict(collections.OrderedDict(sorted(ans.items())))

# %%
sim_to_work[]

# %%
an = pickle.load(open("tmp.pck", "rb"))

# %%
skills_by_theme = collections.defaultdict(lambda: [])

for vac in vacancy_by_name:
    vac = vacancy_by_name[vac]
    skills_by_theme[vac['profession_tree_name']].extend(vac['clear_skills'])

# %%
for skill in skills_by_theme:
    skills_by_theme[skill] = Counter(skills_by_theme[skill]).most_common(30)

# %%
def get_skills(_id):
    if _id in sim_to_work:
        sim = sim_to_work[_id]
        work = vacancy_by_name[sim[0][0]]['profession_tree_name']
        print(work)
        return skills_by_theme[work]
    else:
        return [[None]]

# %%
user = 106

# %%
resume[106]['best']
# Out:
# 'Я специалист в арбитражном процессе. Представлял предприятия в арбитражных (около 200 процессов) и процессах в судах общей юрисдикции (около 70 процессов в основном по сокращению штатов и против "обиженных потребителей", ДТП). В том числе споры по договорам аренды и купли-продажи недвижимости с выселением арендаторов и взысканием арендной платы, банкротства. Имею опыт руководства юридической службы производственных предприятий и предприятий занимающихся розничной торговлей. Представлял доверителей в исполнительном производстве (около 150 производств).\nУверен, что буду Вам полезен.\n\nКомпьютерные навыки:\nПродвинутый пользователь'

# %%
now = get_jobs(user)
old_skills = set()

for key in now.keys():
    tmp = set([i[0] for i in get_skills(now[key]['id'])])
    tmp -= old_skills
    old_skills |= tmp
                     
    print(tmp, end="\n\n")
print("Наши\n:")
print(old_skills)
print("Их:")
print(resume[user]['best'])
# Out:
# Юрист
# {'аналитический склад', 'образование высшее юридическое', 'опытный пользователь', 'трудового права', 'желание', 'грамотная письменная речь', 'знание законодательства', 'знание гражданского', 'правовая специализация', 'умение с большим объемом информации', 'высшее юридическое образование', 'умение в режиме многозадачности', 'умение', 'опыт работы по специальности', 'знание гражданского законодательства', 'опыт договорной работы', 'уверенный пользователь', 'опыт работы', 'опыт работы в аналогичной должности', 'стаж работы', 'высшее образование', 'юридическое образование', 'административного права', 'грамотная речь', 'умение в команде', 'опыт работы юристом', 'высокая работоспособность', 'образование высшее', 'нацеленность на результат', 'грамотная устная'}
#
# Юрист
# set()
#
# Наши
# :
# {'аналитический склад', 'образование высшее юридическое', 'умение', 'опыт работы по специальности', 'знание гражданского законодательства', 'опытный пользователь', 'трудового права', 'опыт договорной работы', 'желание', 'грамотная письменная речь', 'уверенный пользователь', 'опыт работы', 'опыт работы в аналогичной должности', 'знание законодательства', 'стаж работы', 'знание гражданского', 'высшее образование', 'юридическое образование', 'административного права', 'правовая специализация', 'умение с большим объемом информации', 'грамотная речь', 'умение в команде', 'опыт работы юристом', 'высшее юридическое образование', 'высокая работоспособность', 'образование высшее', 'умение в режиме многозадачности', 'нацеленность на результат', 'грамотная устная'}
# Их:
# Я специалист в арбитражном процессе. Представлял предприятия в арбитражных (около 200 процессов) и процессах в судах общей юрисдикции (около 70 процессов в основном по сокращению штатов и против "обиженных потребителей", ДТП). В том числе споры по договорам аренды и купли-продажи недвижимости с выселением арендаторов и взысканием арендной платы, банкротства. Имею опыт руководства юридической службы производственных предприятий и предприятий занимающихся розничной торговлей. Представлял доверителей в исполнительном производстве (около 150 производств).
# Уверен, что буду Вам полезен.
#
# Компьютерные навыки:
# Продвинутый пользователь

# %%
vacancy_by_name[sim_to_work[1][1][0]]
# Out:
# {'candidat': 'Опыт работы от 2х лет\nУверенные теоретические знания в области экономики и финансов, хорошее знание 1С упп, уверенное знание Excel, MS Office уверенный пользователь ПК',
#  'clear_skills': ['опыт работа',
#   'уверенный теоретический знание область финансы',
#   'уверенный теоретический знание область экономика',
#   'уверенный знание',
#   'уверенный пользователь'],
#  'dirty_skills': ['опыт работы',
#   'уверенные теоретические знания в области финансов',
#   'уверенные теоретические знания в области экономики',
#   'уверенное знание',
#   'уверенный пользователь'],
#  'drive_license': '',
#  'education_value': 'высшее',
#  'employer_type_value': 'аутсорс/аутстаф',
#  'experience_value': 'от 1 до 3 лет',
#  'id': '04b50f2e2639690246cce43fdc85bd3569d91d27',
#  'id_client': '94ddac0871a6bf0db20e5ecd62e0aef189df6386',
#  'languages': [],
#  'metro': [],
#  'payment_from': 46000,
#  'payment_to': 52000,
#  'place_of_work_value': 'на территории работодателя',
#  'profession': 'Финансовый менеджер',
#  'profession_tree_id': 990,
#  'profession_tree_name': 'Финансовый менеджер',
#  'town': 'Москва',
#  'type_of_work_value': 'полный рабочий день',
#  'vac': array([ -2.31260378e-02,  -4.17117961e-03,  -1.43394331e-02,
#           7.33572012e-03,  -1.88420096e-03,  -2.20646057e-02,
#          -2.26537734e-02,  -1.67409983e-02,  -6.21176884e-03,
#          -1.37186451e-02,  -1.15840966e-02,  -1.67430770e-02,
#          -1.11083956e-02,   1.02688847e-02,   1.29507016e-03,
#          -1.20355822e-02,  -1.44751007e-02,   1.07675167e-02,
#           1.50286416e-02,   1.32523365e-02,  -1.85281578e-02,
#          -5.81896165e-04,   3.36993709e-02,  -1.32765633e-03,
#          -2.64738500e-02,   1.01559320e-02,   1.20479921e-02,
#          -3.75438482e-02,  -4.79070358e-02,  -2.62248795e-04,
#          -8.66888557e-03,   5.88456541e-03,  -7.58135982e-04,
#           8.37387424e-03,  -6.10091491e-03,  -9.91510134e-03,
#          -1.64056551e-02,  -1.58951851e-03,  -4.26749289e-02,
#           2.66621783e-02,   2.73731966e-02,   9.40577220e-03,
#           1.30691929e-02,  -2.90716048e-02,  -5.87278605e-03,
#           1.73636980e-03,   2.53150612e-02,   4.67638522e-02,
#           4.70759682e-02,  -4.55493340e-03,  -1.87841970e-02,
#          -8.58756248e-03,   7.30197586e-04,  -8.94517358e-03,
#           6.56828331e-03,   4.57074726e-03,  -2.02491172e-02,
#           1.84184534e-03,   9.54348687e-03,  -3.59405465e-02,
#           4.11229761e-04,  -1.71325263e-02,  -2.48476807e-02,
#          -1.70475636e-02,  -1.72819700e-02,   1.94305759e-02,
#           5.89814968e-04,   3.01219989e-02,   5.71190706e-03,
#          -8.73240735e-03,   2.39999909e-02,  -2.79984605e-02,
#           2.44794507e-02,  -3.03454231e-03,  -8.35337769e-03,
#           8.44901707e-03,   1.66621320e-02,  -2.31882930e-02,
#           1.79563519e-02,   2.95067369e-03,  -1.85042073e-03,
#          -3.31434608e-03,   1.49893509e-02,  -2.65243929e-02,
#          -1.86058190e-02,   4.76708589e-03,  -2.14449167e-02,
#          -2.79704034e-02,   1.38257472e-02,  -4.34766384e-03,
#           1.26599483e-02,   5.75437211e-03,   1.02985920e-02,
#           2.83826631e-03,  -3.21550108e-02,   2.03934889e-02,
#          -1.39349699e-02,  -1.06965797e-02,   1.65716454e-03,
#          -4.25204961e-03,   1.99552290e-02,  -1.59293711e-02,
#          -2.22301036e-02,   1.55479126e-02,  -4.09517577e-03,
#           4.10956927e-02,   1.32959301e-03,   2.19585057e-02,
#           1.22779086e-02,  -4.97886678e-03,  -2.47112662e-02,
#           2.23282743e-02,  -1.14684772e-04,   3.44678946e-02,
#           3.57546494e-03,  -2.76344437e-02,  -2.66167969e-02,
#           9.45106428e-03,  -1.12222368e-02,   1.95568968e-02,
#           1.29967565e-02,   1.39928563e-02,  -1.69485863e-02,
#          -3.43095069e-03,  -3.69051956e-02,   2.96605155e-02,
#           4.37342329e-03,   3.91988419e-02,   7.06412503e-03,
#          -1.42885419e-02,  -4.58782203e-02,  -1.11677067e-03,
#           6.16158685e-03,  -1.02952104e-02,  -3.54863293e-02,
#          -2.91177537e-02,   3.89936008e-03,   2.45805066e-02,
#           2.14720704e-03,  -2.45776344e-02,   1.15728076e-03,
#           2.36544516e-02,   1.63743068e-02,  -6.94369571e-03,
#           3.31751443e-02,  -2.53270590e-03,   1.15614785e-02,
#          -4.32025781e-03,   9.81388148e-03,  -9.23363958e-03,
#           1.27764838e-02,   2.74004191e-02,   8.94557626e-04,
#          -2.23911330e-02,  -2.88784895e-02,   1.20656937e-02,
#          -1.49479806e-02,  -3.43887955e-02,   1.28636053e-02,
#          -1.68065261e-02,   3.48177217e-02,   7.95013085e-03], dtype=float32),
#  'work': 'Анализ и контроль оборотных активов - денежные средства, дебиторка.\nСоставление реестра платежей\nКонтроль плановых поступлений ДС - предоставление оперативной регулярной информации руководству компании.\nАнализ дебиторской\nСверка с контрагентами'}

# %%
def career(jobs):
    ans = list()
    for key in jobs:
        ans.append(vacancy_by_name[sim_to_work[jobs[key]['id']][0][0]]['profession_tree_name'])
    return ans

# %%
career(get_jobs(0))
# Out:
# ['Промоутер',
#  'Кладовщик',
#  'Торговый представитель',
#  'Экономист аналитик',
#  'Финансовый директор',
#  'Финансовый директор',
#  'Финансовый директор',
#  'Финансовый директор',
#  'Финансовый менеджер']
